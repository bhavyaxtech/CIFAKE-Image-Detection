# %% [markdown]
# # CIFAKE: AI-Generated Image Detection & Explainability
# This notebook drives the full pipeline (setup, training, evaluation, prediction, Grad-CAM) using the project's `src/` modules. Designed for Google Colab.
#
# **Steps:**
# 1. Mount Drive / clone project
# 2. Install dependencies
# 3. Set up the CIFAKE dataset
# 4. Train the model
# 5. Evaluate
# 6. Predict on new images
# 7. Generate Grad-CAM explanations

# %%
# If running in Colab, upload/clone the project folder so this notebook
# sits at project/notebooks/ with sibling src/, dataset/, outputs/ dirs.
import os
PROJECT_ROOT = os.path.abspath(os.path.join(os.getcwd(), os.pardir))
os.chdir(PROJECT_ROOT)
print('Working directory:', os.getcwd())

# %%
# !pip install -q -r requirements.txt

# %% [markdown]
# ## Dataset Setup
# Download the CIFAKE dataset from Kaggle and place it under `dataset/train` and `dataset/test`. See `README.md` Section 4 for details.

# %%
# Example (requires a Kaggle API token uploaded as kaggle.json):
# !mkdir -p ~/.kaggle && cp kaggle.json ~/.kaggle/
# !kaggle datasets download -d birdy654/cifake-real-and-ai-generated-synthetic-images
# !unzip -q cifake-real-and-ai-generated-synthetic-images.zip -d dataset

# %% [markdown]
# ## Train the Model

# %%
from src.train import run_training
from src.evaluate import plot_training_history

model, history = run_training(epochs=50)
plot_training_history(history)

# %% [markdown]
# ## Evaluate on the Test Set

# %%
from src.data_loader import CIFAKEDataLoader
from src.evaluate import evaluate_model

loader = CIFAKEDataLoader()
_, _, test_ds = loader.load_datasets(augment_train=False)
metrics = evaluate_model(model, test_ds)
metrics

# %% [markdown]
# ## Predict a Single Image

# %%
from src.predict import predict_single_image

result = predict_single_image(model, 'dataset/test/REAL/0.jpg')  # update path as needed
result

# %% [markdown]
# ## Grad-CAM Explanation

# %%
from src.gradcam import explain_image
from IPython.display import Image, display

label, path, score = explain_image(model, 'dataset/test/REAL/0.jpg')  # update path as needed
print(label, score)
display(Image(filename=path))
